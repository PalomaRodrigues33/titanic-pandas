# %%
df[1:-1]
# Out:
#                    A         B         C         D
# 2013-01-02  1.462859 -1.958458 -0.739962 -2.010407
# 2013-01-03 -1.513370 -0.563800 -0.585426  0.376669
# 2013-01-04 -0.950253  1.891354  0.748798  1.109644
# 2013-01-05  0.319832 -1.211043  2.228859  1.525523

# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02  1.462859 -1.958458 -0.739962 -2.010407
# 2013-01-03 -1.513370 -0.563800 -0.585426  0.376669
# 2013-01-04 -0.950253  1.891354  0.748798  1.109644

# %%
df.loc[dates[0]]
# Out:
# A    0.977869
# B   -0.210599
# C   -0.191234
# D    0.885215
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01  0.977869 -0.210599
# 2013-01-02  1.462859 -1.958458
# 2013-01-03 -1.513370 -0.563800
# 2013-01-04 -0.950253  1.891354
# 2013-01-05  0.319832 -1.211043
# 2013-01-06 -1.077111  0.741374

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02  1.462859 -1.958458
# 2013-01-03 -1.513370 -0.563800
# 2013-01-04 -0.950253  1.891354

# %%
df.loc[dates[0], "A"]
# Out:
# 0.9778687302795387

# %%
df.at[dates[0], "A"]
# Out:
# 0.9778687302795387

# %%
df.iloc[3]
# Out:
# A   -0.950253
# B    1.891354
# C    0.748798
# D    1.109644
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04 -0.950253  1.891354
# 2013-01-05  0.319832 -1.211043

# %%
df.iloc[[1,2,4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02  1.462859 -0.739962
# 2013-01-03 -1.513370 -0.585426
# 2013-01-05  0.319832  2.228859

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02  1.462859 -1.958458 -0.739962 -2.010407
# 2013-01-03 -1.513370 -0.563800 -0.585426  0.376669

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01 -0.210599 -0.191234
# 2013-01-02 -1.958458 -0.739962
# 2013-01-03 -0.563800 -0.585426
# 2013-01-04  1.891354  0.748798
# 2013-01-05 -1.211043  2.228859
# 2013-01-06  0.741374 -2.286122

# %%
df.iloc[1, 1]
# Out:
# -1.9584578494928042

# %%
df.iat[1, 1]
# Out:
# -1.9584578494928042

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.977869 -0.210599 -0.191234  0.885215
# 2013-01-02  1.462859 -1.958458 -0.739962 -2.010407
# 2013-01-05  0.319832 -1.211043  2.228859  1.525523

# %%
df[df > 0]

# %%
df2 = df.copy()

df2["E"] = ["one", "one", "two", "three", "four", "three"]

df2
# Out:
#                    A         B         C         D     E
# 2013-01-03 -1.513370 -0.563800 -0.585426  0.376669   two
# 2013-01-05  0.319832 -1.211043  2.228859  1.525523  four

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -1.513370 -0.563800 -0.585426  0.376669   two
# 2013-01-05  0.319832 -1.211043  2.228859  1.525523  four

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))

df["F"] = s1

s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df.at[dates[0], "A"] = 0

# %%
df.iat[0, 1] = 0

# %%
df.loc[:, "D"] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.191234  5.0  NaN
# 2013-01-02  1.462859 -1.958458 -0.739962  5.0  1.0
# 2013-01-03 -1.513370 -0.563800 -0.585426  5.0  2.0
# 2013-01-04 -0.950253  1.891354  0.748798  5.0  3.0
# 2013-01-05  0.319832 -1.211043  2.228859  5.0  4.0
# 2013-01-06 -1.077111  0.741374 -2.286122  5.0  5.0

# %%
df2 = df.copy()

df2[df2 > 0] = -df2

df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.191234 -5.0  NaN
# 2013-01-02 -1.462859 -1.958458 -0.739962 -5.0 -1.0
# 2013-01-03 -1.513370 -0.563800 -0.585426 -5.0 -2.0
# 2013-01-04 -0.950253 -1.891354 -0.748798 -5.0 -3.0
# 2013-01-05 -0.319832 -1.211043 -2.228859 -5.0 -4.0
# 2013-01-06 -1.077111 -0.741374 -2.286122 -5.0 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

df1.loc[dates[0] : dates[1], "E"] = 1

df1
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000 -0.191234  5.0  NaN  1.0
# 2013-01-02  1.462859 -1.958458 -0.739962  5.0  1.0  1.0
# 2013-01-03 -1.513370 -0.563800 -0.585426  5.0  2.0  NaN
# 2013-01-04 -0.950253  1.891354  0.748798  5.0  3.0  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C    D    F    E
# 2013-01-02  1.462859 -1.958458 -0.739962  5.0  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000 -0.191234  5.0  5.0  1.0
# 2013-01-02  1.462859 -1.958458 -0.739962  5.0  1.0  1.0
# 2013-01-03 -1.513370 -0.563800 -0.585426  5.0  2.0  5.0
# 2013-01-04 -0.950253  1.891354  0.748798  5.0  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df.mean()

# %%
df.mean(axis=1)

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)

s
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -2.513370 -1.563800 -1.585426  4.0  1.0
# 2013-01-04 -3.950253 -1.108646 -2.251202  2.0  0.0
# 2013-01-05 -4.680168 -6.211043 -2.771141  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -2.513370 -1.563800 -1.585426  4.0  1.0
# 2013-01-04 -3.950253 -1.108646 -2.251202  2.0  0.0
# 2013-01-05 -4.680168 -6.211043 -2.771141  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df.agg(lambda x: np.mean(x) * 5.6)
# Out:
# A    -1.640840
# B    -1.027201
# C    -0.770082
# D    28.000000
# F    16.800000
# dtype: float64

# %%
df.transform(lambda x: x * 101.2)
# Out:
#                      A           B           C      D      F
# 2013-01-01    0.000000    0.000000  -19.352872  506.0    NaN
# 2013-01-02  148.041343 -198.195934  -74.884164  506.0  101.2
# 2013-01-03 -153.153078  -57.056564  -59.245114  506.0  202.4
# 2013-01-04  -96.165633  191.405046   75.778361  506.0  303.6
# 2013-01-05   32.367004 -122.557527  225.560524  506.0  404.8
# 2013-01-06 -109.003607   75.027065 -231.355591  506.0  506.0

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

s
# Out:
# 0    3
# 1    6
# 2    1
# 3    4
# 4    5
# 5    1
# 6    5
# 7    2
# 8    3
# 9    1
# dtype: int64

# %%
s.value_counts()
# Out:
# 1    3
# 3    2
# 5    2
# 6    1
# 4    1
# 2    1
# Name: count, dtype: int64

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))

df
# Out:
#           0         1         2         3
# 0 -0.312903 -0.346252  0.155485 -1.535725
# 1  1.030677  1.540025 -1.399897  0.903060
# 2  0.049332 -0.169647 -2.050858 -1.082287
# 3 -0.870017 -1.522514  0.238875 -1.030334
# 4  0.698159 -2.179693  0.065000  1.927991
# 5 -0.643184  0.233782 -1.127334  1.311853
# 6  0.750530  1.175093  0.728797 -1.117674
# 7  0.112740  0.288158  0.417987 -0.752329
# 8  0.206596 -0.113864 -1.115458  1.420869
# 9 -0.716292  0.191627  0.631359 -0.646455

# %%
pieces = [df[:3], df[3:7], df[7:]]

pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.312903 -0.346252  0.155485 -1.535725
# 1  1.030677  1.540025 -1.399897  0.903060
# 2  0.049332 -0.169647 -2.050858 -1.082287
# 3 -0.870017 -1.522514  0.238875 -1.030334
# 4  0.698159 -2.179693  0.065000  1.927991
# 5 -0.643184  0.233782 -1.127334  1.311853
# 6  0.750530  1.175093  0.728797 -1.117674
# 7  0.112740  0.288158  0.417987 -0.752329
# 8  0.206596 -0.113864 -1.115458  1.420869
# 9 -0.716292  0.191627  0.631359 -0.646455

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})

right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})

right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})

pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)


df
# Out:
#      A      B         C         D
# 0  foo    one -1.191384 -0.370557
# 1  bar    one  0.109339 -1.873696
# 2  foo    two  1.173998 -1.074583
# 3  bar  three -0.409841 -0.899401
# 4  foo    two -0.297017  0.545418
# 5  bar    two -1.856263 -0.735747
# 6  foo    one -0.607334 -0.989907
# 7  foo  three  1.916738  0.807741

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar -2.156765 -3.508844
# foo  0.995002 -1.081887

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one    0.109339 -1.873696
#     three -0.409841 -0.899401
#     two   -1.856263 -0.735747
# foo one   -1.798718 -1.360464
#     three  1.916738  0.807741
#     two    0.876981 -0.529164

# %%
arrays = [
   ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ["one", "two", "one", "two", "one", "two", "one", "two"],
]


index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])

df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])

df2 = df[:4]

df2
# Out:
#                      A         B
# first second
# bar   one    -0.306781  0.514781
#       two    -1.231574 -0.104489
# baz   one     1.585657  0.319219
#       two    -0.908638 -1.261019

# %%
stacked = df2.stack()

stacked
# Out:
# first  second
# bar    one     A   -0.306781
#                B    0.514781
#        two     A   -1.231574
#                B   -0.104489
# baz    one     A    1.585657
#                B    0.319219
#        two     A   -0.908638
#                B   -1.261019
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.306781  0.514781
#       two    -1.231574 -0.104489
# baz   one     1.585657  0.319219
#       two    -0.908638 -1.261019

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.306781 -1.231574
#       B  0.514781 -0.104489
# baz   A  1.585657 -0.908638
#       B  0.319219 -1.261019

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.306781  1.585657
#        B  0.514781  0.319219
# two    A -1.231574 -0.908638
#        B -0.104489 -1.261019

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)


df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.883564 -1.403782
# 1     one  B  foo  1.915928  0.425988
# 2     two  C  foo -0.146059 -0.092594
# 3   three  A  bar -0.559488 -0.619976
# 4     one  B  bar -2.099605  0.698347
# 5     one  C  bar  0.746536  0.043668
# 6     two  A  foo  0.056010 -0.923766
# 7   three  B  foo -0.103962  0.790072
# 8     one  C  foo -1.299828  0.590149
# 9     one  A  bar -0.285394 -0.235881
# 10    two  B  bar  0.350031 -1.247007
# 11  three  C  bar  1.222275 -0.432562

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A -0.285394 -0.883564
#       B -2.099605  1.915928
#       C  0.746536 -1.299828
# three A -0.559488       NaN
#       B       NaN -0.103962
#       C  1.222275       NaN
# two   A       NaN  0.056010
#       B  0.350031       NaN
#       C       NaN -0.146059

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")

ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

ts.resample("5Min").sum()
# Out:
# 2012-01-01    25124
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

ts = pd.Series(np.random.randn(len(rng)), rng)

ts
# Out:
# 2012-03-06    0.804133
# 2012-03-07    0.109379
# 2012-03-08    1.263782
# 2012-03-09   -0.159905
# 2012-03-10   -0.444046
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    0.804133
# 2012-03-07 00:00:00+00:00    0.109379
# 2012-03-08 00:00:00+00:00    1.263782
# 2012-03-09 00:00:00+00:00   -0.159905
# 2012-03-10 00:00:00+00:00   -0.444046
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00    0.804133
# 2012-03-06 19:00:00-05:00    0.109379
# 2012-03-07 19:00:00-05:00    1.263782
# 2012-03-08 19:00:00-05:00   -0.159905
# 2012-03-09 19:00:00-05:00   -0.444046
# Freq: D, dtype: float64

# %%
rng + pd.offsets.BusinessDay(5)
# Out:
# DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
#                '2012-03-16'],
#               dtype='datetime64[ns]', freq=None)

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

# %%
df["grade"] = df["raw_grade"].astype("category")

df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
new_categories = ["very good", "good", "very bad"]

df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %%
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)


df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade", observed=False).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

ts = ts.cumsum()

ts.plot();

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)


df = df.cumsum()

plt.figure();

df.plot();

plt.legend(loc='best');

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))

df.to_csv("foo.csv")

pd.read_csv("foo.csv")
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  3  3  3  0  0
# 1           1  1  3  0  3  4
# 2           2  2  4  1  2  3
# 3           3  3  4  0  3  3
# 4           4  4  2  4  2  1
# 5           5  4  1  4  3  1
# 6           6  1  2  2  3  4
# 7           7  2  1  2  3  4
# 8           8  4  0  2  4  3
# 9           9  1  0  1  4  0

# %%
df.to_parquet("foo.parquet")

pd.read_parquet("foo.parquet")
# Out:
#    0  1  2  3  4
# 0  2  3  2  3  1
# 1  4  3  3  0  2
# 2  1  2  4  2  0
# 3  4  3  0  3  4
# 4  3  3  2  3  1
# 5  0  4  2  3  2
# 6  3  4  3  1  4
# 7  4  0  0  1  0
# 8  4  4  2  3  1
# 9  2  0  3  2  1

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1")

pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  3  3  3  0  0
# 1           1  1  3  0  3  4
# 2           2  2  4  1  2  3
# 3           3  3  4  0  3  3
# 4           4  4  2  4  2  1
# 5           5  4  1  4  3  1
# 6           6  1  2  2  3  4
# 7           7  2  1  2  3  4
# 8           8  4  0  2  4  3
# 9           9  1  0  1  4  0

# %%
if pd.Series([False, True, False]):
     print("I was true")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-b27eb9c1dfc0> in <cell line: 1>()
# ----> 1 if pd.Series([False, True, False]):
#       2      print("I was true")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1464     @final
#    1465     def __nonzero__(self) -> NoReturn:
# -> 1466         raise ValueError(
#    1467             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
